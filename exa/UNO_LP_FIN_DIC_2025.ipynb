# %% [markdown]
# # UNIVERSIDAD NACIONAL DEL OESTE
# ## Escuela de Informática
# ### Taller de Lenguajes de Programación
# #### Profesores: Mag. Ing. Pablo Pandolfo / Anta. Alexander Andrada
# #### Examen Final - Diciembre 2025

# %% [markdown]
# * **ALUMNO**:
# * **DNI**:

# %% [markdown]
# 1. Justifíquese: **"La mayoría de los lenguajes de programación web son interpretados"**

# %% [markdown]
# 2. Enumérese cinco características del **Paradigma Lógico**

# %% [markdown]
# 3. Diséñese BNF del **Lenguaje Colchita**. Constrúyase el árbol de análisis sintáctico para **coser(girar(retazo1), retazo2)**. Proponer una semántica adecuada al lenguaje

# %% [markdown]
# 4. Desarróllese un programa que valide el acceso a una página web (**status code 200**)

# %% [markdown]
# 5. Desarróllese un programa que busque en Google **WEB** y valide que el título de la página es **WEB - Buscar con Google**
