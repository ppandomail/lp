# %% [markdown]
# # Web Scraping
# ---

# %% [markdown]
# ## ¿Qué es el web scraping?

# %% [markdown]
# * Es la técnica/proceso automatizado de extraer datos de sitios web y transformarlos en un formato estructurado, como CSV, JSON o una base de datos
# * Consiste en realizar solicitudes a páginas web, obtener su contenido (generalmente HTML) y procesarlo para extraer la información deseada.

# %% [markdown]
# ## Usos

# %% [markdown]
# * Recopilación de datos para investigación
# * Buscar ofertas laborales, productos, servicios, etc.
# * Obtener las cotizaciones de las acciones para tomar mejores decisiones de inversión
# * Comparación de precios de vuelos, hoteles, etc.
# * Generación de bases de datos
# * Automatización de tareas
# * Monitoreo de redes sociales (opiniones, noticias)
# * Monitoreo de cambios en páginas web

# %% [markdown]
# ## ¿Es legal el web scraping?

# %% [markdown]
# * La legalidad del web scraping depende de las condiciones de servicio del sitio web y de las leyes aplicables, como la normativa sobre derechos de autor y privacidad de datos
# * Es importante tener en cuenta que no todo dato publicado en un sitio web puede ser extraído sin restricciones. Las consideraciones incluyen:
#     * Revisar el archivo `robots.txt` de la web para respetar reglas de acceso
#     * No saturar el servidor con demasiadas peticiones en poco tiempo
#     * Respetar la propiedad intelectual y términos de uso
#     * Evitar extraer datos personales sensibles

# %% [markdown]
# ## ¿Qué es un archivo robots.txt y por qué es importante?

# %% [markdown]
# * Es un documento de texto colocado en la raíz de un sitio web que indica a los rastreadores de motores de búsqueda qué páginas o directorios pueden o no pueden ser accedidos y analizados
# * Funciona mediante instrucciones simples, llamadas directivas, que guían a los bots sobre qué contenido rastrear o ignorar
# * Ayuda a gestionar la carga del servidor y evitar que se indexen páginas no deseadas, pero solo influye en bots respetuosos y no en aquellos que actúan de forma maliciosa o que no respetan estas reglas
# * Por ejemplo, con una línea como **Disallow: /private/**, se bloquea el acceso a esa carpeta específica

# %% [markdown]
# ## ¿Qué herramientas son adecuadas para el scraping de sitios web estáticos?

# %% [markdown]
# Herramientas como BeautifulSoup o Requests son adecuadas para el scraping de pequeños proyectos, mientras que Scrapy y lxml son adecuadas para grandes proyectos con sitios web estáticos

# %% [markdown]
# ## ¿Qué herramientas son adecuadas para el scraping de sitios web?

# %% [markdown]
# * **Requests**: permite realizar solicitudes HTTP para obtener el contenido HTML de páginas web. Es sencilla y eficiente para páginas estáticas
# * **BeautifulSoup**: es una librería para analizar (parsear) documentos HTML o XML. Facilita navegar, buscar y extraer partes específicas del contenido HTML descargado
# * **Scrapy**: framework completo para scraping avanzado. Permite crear proyectos potentes para extraer datos de múltiples páginas y manejar sesiones, seguimientos y reglas complejas
# * **Selenium**: herramienta para automatizar navegadores web. Útil para páginas con contenido dinámico generado por JavaScript, donde Requests y BeautifulSoup no son suficientes

# %% [markdown]
# **Uso conjunto**: lo común es usar primero **requests** para descargar el contenido, luego **BeautifulSoup** para extraer datos. Para proyectos complejos o con contenido dinámico, **Selenium** o **Scrapy** son más adecuados

# %% [markdown]
# ## Ejemplo Population by country

# %% [markdown]
# * Scraping de datos sobre la población del mundo
# * Datos disponibles en sitio **Worldometers**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import plotly.express as px
from io import StringIO

# %%
res = requests.get('https://www.worldometers.info/world-population/population-by-country/')

# %%
res.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(res.text)
data = soup.find_all("table")[0]
df_population = pd.read_html(StringIO(str(data)))[0]
df_population.head()
# Out:
#    # Country (or dependency)  Population 2026 Yearly Change    Net Change  \
# 0  1                   India       1476625576         0.87%      12760051
# 1  2                   China       1412914089      â0.22%  â3,182,005
# 2  3           United States        349035494         0.51%       1759687
# 3  4               Indonesia        287886782         0.76%       2165546
# 4  5                Pakistan        259299791          1.6%       4080237
#
#    Density (P/KmÂ²)  Land Area (KmÂ²) Migrants (net)  Fert. Rate  Median Age  \
# 0               497           2973190     â440,456        1.93        29.2
# 1               150           9388211     â232,107        1.03        40.6
# 2                38           9147420        1177848        1.63        38.7
# 3               159           1811570      â39,472        2.08        30.7
# 4               336            770880   â1,144,738        3.44        20.8
#
#   Urban Pop % World Share
# 0       37.6%       17.8%
# ...

# %%
df_population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   #                        234 non-null    int64
#  1   Country (or dependency)  234 non-null    object
#  2   Population 2026          234 non-null    int64
#  3   Yearly Change            234 non-null    object
#  4   Net Change               234 non-null    object
#  5   Density (P/KmÂ²)         234 non-null    int64
#  6   Land Area (KmÂ²)         234 non-null    int64
#  7   Migrants (net)           234 non-null    object
#  8   Fert. Rate               234 non-null    float64
#  9   Median Age               234 non-null    float64
#  10  Urban Pop %              234 non-null    object
#  11  World Share              234 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 22.1+ KB

# %%
df_population['Population 2026']
# Out:
# 0      1476625576
# 1      1412914089
# 2       349035494
# 3       287886782
# 4       259299791
#           ...
# 229          4328
# 230          3465
# 231          2691
# 232          1822
# 233           506
# Name: Population 2026, Length: 234, dtype: int64

# %%
df_population_filter = df_population[df_population['Population 2026'] > 25000000]
fig = px.bar(df_population_filter, x = 'Country (or dependency)', y = 'Population 2026')
fig.show()

# %% [markdown]
# ## Ejemplo TIOBE

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# El ejemplo muestra cómo obtener el contenido HTML y extraer el título de la página

# %%
try:
    response = requests.get('https://www.tiobe.com/tiobe-index/', timeout=10)
    response.raise_for_status()  # Verifica que la respuesta sea exitosa
except requests.RequestException as e:
    print(f'Error al acceder a la página: {e}')
else:
    soup = BeautifulSoup(response.text, 'html.parser')
    print('Título de la página: ', soup.title.string)
# Out:
# Título de la página:  TIOBE Index - TIOBE

# %% [markdown]
# * El contenido de una página web está estructurado en HTML, que utiliza etiquetas (tags) para organizar texto, imágenes y otros elementos
# * Para extraer datos, el scraper debe localizar los elementos HTML que contienen la información deseada
# * Esto se suele hacer buscando etiquetas específicas, clases CSS, IDs o atributos únicos
# * Técnicas comunes para localizar elementos
#     * **Selectores CSS**: selectores como `.clase`, `#id` o `tag` para seleccionar elementos
#     * **BeautifulSoup**: funciones como `find()` para buscar un solo elemento y `find_all()` para múltiples
#     * **XPath**: método alternativo para seleccionar nodos en un documento HTML o XML (más avanzado)

# %% [markdown]
# El ejemplo muestra cómo extraer los n primeros lenguajes más usados en el índice TIOBE

# %%
soup = BeautifulSoup(response.text, 'html.parser')
tabla = soup.find('table', {'class': 'table-top20'})
top_n = 10

if tabla:
    datos_tiobe = []
    filas = tabla.find_all('tr')[1:top_n+1]
    for fila in filas:
        celdas = fila.find_all('td')
        if len(celdas) >= 7:
            posicion = celdas[0].get_text(strip=True)
            lenguaje = celdas[4].get_text(strip=True)
            porcentaje = float(celdas[5].get_text(strip=True).replace('%',''))
            datos_tiobe.append({'posicion': posicion, 'lenguaje': lenguaje, 'porcentaje': porcentaje})
else:
    print('No se encontró la tabla Top 20 en la página.')
df = pd.DataFrame(datos_tiobe)
df
# Out:
#   posicion      lenguaje  porcentaje
# 0        1        Python       18.53
# 1        2             C       11.10
# 2        3           C++        8.62
# 3        4          Java        8.25
# 4        5            C#        4.09
# 5        6    JavaScript        2.63
# 6        7  Visual Basic        2.18
# 7        8           SQL        1.88
# 8        9             R        1.56
# 9       10          Rust        1.45

# %%
df.plot(x='lenguaje', y='porcentaje', kind='bar', legend=False)
plt.title(f'Top {top_n} Lenguajes TIOBE')
plt.ylabel('Porcentaje')
plt.show()

# %%
df.to_csv(f'data/tiobe_ultimo_ano_top{top_n}.csv', index=False, encoding='utf-8')
