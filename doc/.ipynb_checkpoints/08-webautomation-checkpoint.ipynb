# %% [markdown]
# # Web Automation
# ---

# %% [markdown]
# [https://selenium-python.readthedocs.io/](https://selenium-python.readthedocs.io/)

# %% [markdown]
# * **Automatizar procesos**: descargar datos, completar formularios, generación de backups, procesamientos de datos, etc.
# * **Automatizar el testeo** (qa automation): validar que los datos ingresados (trámites a distancia TAD) persistan en la BD, validar movimientos financieros, etc.

# %% [markdown]
# * Objetivos: desarrollar un programa
#     * para mejorar la eficiencia (tiempos) operativa
#     * que valide funcionalidades de una aplicación web

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

import time

# %% [markdown]
# ## Ejemplo www.google.com

# %%
# Inicializar el WebDriver (Chrome en este caso)
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

# Navegar a una página web
driver.get("https://www.google.com")

# Obtener el título de la página
titulo = driver.title
print(f"Título de la página: {titulo}")

pie = driver.find_element(By.XPATH, "//div[@class='uU7dJb']").text
print(f"Pie de la página: {pie}")

# Cerrar el navegador
driver.quit()
# Out:
# Título de la página: Google
# Pie de la página: Argentina

# %% [markdown]
# ## Ejemplo www.python.org locator NAME

# %%
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
driver.get('https://www.python.org')

# Permite realizar comprobaciones (test unitarios)
# Si la expresión es False, se lanzará la excepción AssertionError
assert "Python" in driver.title, 'Python está en el título'
elem = driver.find_element(By.NAME, "q")
elem.clear()
elem.send_keys("pycon")
elem.send_keys(Keys.RETURN)
assert "No results found." not in driver.page_source
driver.close()

# %% [markdown]
# ## Ejemplo www.python.org locator LINK TEXT

# %%
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
driver.get('http://www.python.org')   
driver.find_element(By.LINK_TEXT, "Docs").click()
elem2 = driver.find_element(By.TAG_NAME, "h1")
assert elem2.text == "Python 3.14.0 documentation"
driver.close()

# %% [markdown]
# ## Ejemplo www.python.org locator XPATH

# %%
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
driver.get('http://www.python.org')
driver.find_element(By.XPATH, "//*[@id='top']/nav/ul/li[3]/a").click()
elem2 = driver.find_element(By.TAG_NAME, "h1")
assert elem2.text == "Python 3.14.0 documentation"
driver.close()

# %% [markdown]
# ## Ejemplo www.automationpractice.pl

# %%
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
driver.get('http://www.automationpractice.pl/index.php')
driver.find_element(By.ID, 'search_query_top').send_keys('Hola')
driver.find_element(By.NAME, 'submit_search').click()
time.sleep(10)
actual = driver.find_element(By.XPATH, '//*[@id="center_column"]/p').text
assert actual == 'No results were found for your search "Hola"'
time.sleep(2)
driver.find_element(By.LINK_TEXT, "Women").click()
time.sleep(2)
driver.find_element(By.PARTIAL_LINK_TEXT, "Dres").click()
time.sleep(2)
driver.close()

# %% [markdown]
# ## Ejemplo accediendo a la subpágina de www.uno.edu.ar

# %%
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
driver.get('https://www.uno.edu.ar/oferta-academica/tecnicaturas/tec-univ-en-tecnologias-web.html')
web_element = driver.find_element(By.XPATH, "//strong[text()='Duración de la carrera: ']/ancestor::span")
assert "2 años y medio." in web_element.text
driver.close()

# %% [markdown]
# ## Ejemplo navegando hacia la carrera

# %%
from selenium.webdriver.common.action_chains import ActionChains

driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
driver.get("https://www.uno.edu.ar")
actions = ActionChains(driver)
oferta = driver.find_element(By.LINK_TEXT, "OFERTA ACADÉMICA")
actions.move_to_element(oferta).perform()
pregrado = driver.find_element(By.LINK_TEXT, "PREGRADO")
actions.move_to_element(pregrado).perform()
tec_web = driver.find_element(By.LINK_TEXT, "TEC. UNIV. EN TECNOLOGÍAS WEB")
tec_web.click()
web_element = driver.find_element(By.XPATH, "//strong[text()='Duración de la carrera: ']/ancestor::span")
assert "2 años y medio" in web_element.text
driver.close()

# %% [markdown]
# ## Webs para practicar

# %% [markdown]
# 1. 𝗣𝗿𝗮𝗰𝘁𝗶𝗰𝗲 𝗧𝗲𝘀𝘁 𝗔𝘂𝘁𝗼𝗺𝗮𝘁𝗶𝗼𝗻 (https://practicetestautomation.com/)
#     * login y validaciones
# 2. 𝗧𝗵𝗲 𝗜𝗻𝘁𝗲𝗿𝗻𝗲𝘁 (https://the-internet.herokuapp.com/)
#     * alerts, waits, drag & drop
# 3. 𝗧𝗲𝘀𝘁𝗶𝗻𝗴 𝗔𝗿𝗲𝗻𝗮 (https://automationtesting.co.uk/)
#     * formularios y tablas
# 4. 𝗗𝗲𝗺𝗼𝗤𝗔 (https://demoqa.com/)
#     * UI dinámica (React)
# 5. 𝗦𝗮𝘂𝗰𝗲𝗗𝗲𝗺𝗼 (https://www.saucedemo.com/)
#     * login + carrito
# 6. 𝗖𝗲𝗻𝘁𝘆𝗰 𝗣𝗿𝗮́𝗰𝘁𝗶𝗰𝗮 𝗘𝗰𝗼𝗺𝗺𝗲𝗿𝗰𝗲 (https://centyc.cl/practica/)
#     * ecommerce completo para pruebas end-to-end, desde el login hasta la confirmación de compra. (Ideal para flujos reales y validaciones complejas)
# 7. 𝗧𝗲𝘀𝘁𝗶𝗺 𝗗𝗲𝗺𝗼 (https://demo.testim.io/)
#     * login y flujos de reserva
